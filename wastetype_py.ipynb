# %% [markdown]
# <a href="https://colab.research.google.com/github/gusha-2908/waste-type/blob/main/wastetype_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn. metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import joblib

# %%
data=pd.read_csv("/content/waste_classification_dataset_500.csv")
print(data.head())
# Out:
#    Weight(g)  Moisture(%)  Hardness  Magnetic  Biodegradable WasteType
# 0         30            3         1         0              0   Plastic
# 1        190            2         8         1              0     Metal
# 2         78           78         1         0              1   Organic
# 3         79            2         7         0              0     Glass
# 4         48            3         3         0              0     Paper

# %%
x=data.drop("WasteType", axis=1)
y=data["WasteType"]

# %%
encoder=LabelEncoder()
y=encoder.fit_transform(y)
y
# Out:
# array([4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1,
#        2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0,
#        3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4,
#        1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2,
#        0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3,
#        4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1,
#        2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0,
#        3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4,
#        1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2,
#        0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3,
#        4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1,
#        2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0,
#        3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4,
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
lr_pred=lr.predict(x_test)
lr_pred
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# array([1, 0, 0, 4, 3, 3, 2, 3, 0, 3, 3, 3, 1, 3, 1, 0, 4, 4, 1, 0, 4, 1,
#        4, 1, 1, 1, 2, 1, 1, 3, 3, 1, 4, 0, 2, 0, 3, 4, 3, 0, 3, 0, 4, 4,
#        0, 2, 4, 1, 4, 2, 2, 2, 1, 4, 0, 3, 0, 0, 3, 0, 3, 2, 0, 3, 4, 3,
#        1, 1, 1, 1, 2, 1, 2, 4, 2, 3, 0, 0, 3, 4, 3, 2, 2, 2, 1, 4, 4, 3,
#        2, 0, 1, 2, 2, 0, 1, 2, 1, 4, 0, 4])

# %%
print("Logistic Regression Accuracy")
print(accuracy_score(y_test,lr_pred))
print("\nclassification Report")
print(classification_report(y_test,lr_pred))
print("\nconfusion Mateix")
print(confusion_matrix(y_test,lr_pred))
# Out:
# Logistic Regression Accuracy
# 0.9
#
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87        19
#            1       0.95      1.00      0.98        21
#            2       1.00      1.00      1.00        18
#            3       0.76      0.80      0.78        20
#            4       0.95      0.82      0.88        22
#
#     accuracy                           0.90       100
#    macro avg       0.90      0.90      0.90       100
# weighted avg       0.90      0.90      0.90       100
#
#
# confusion Mateix
# [[17  1  0  1  0]
#  [ 0 21  0  0  0]
#  [ 0  0 18  0  0]
#  [ 3  0  0 16  1]
#  [ 0  0  0  4 18]]

# %%
joblib.dump(lr,'waste Type classification_Logistic_regression.pkl')
# Out:
# ['waste Type classification_Logistic_regression.pkl']

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier(random_state=42)
dt.fit(x_train,y_train)
dt_pred=dt.predict(x_test)

# %%
print("Decision Tree Accuracy")
print(accuracy_score(y_test,dt_pred))
print("\nClassification Report ")
print(classification_report(y_test,dt_pred))
print("\nconfusion Mateix")
print(confusion_matrix(y_test,dt_pred))
# Out:
# Decision Tree Accuracy
# 0.95
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.94      0.89      0.92        19
#            1       1.00      1.00      1.00        21
#            2       1.00      1.00      1.00        18
#            3       0.86      0.90      0.88        20
#            4       0.95      0.95      0.95        22
#
#     accuracy                           0.95       100
#    macro avg       0.95      0.95      0.95       100
# weighted avg       0.95      0.95      0.95       100
#
#
# confusion Mateix
# [[17  0  0  2  0]
#  [ 0 21  0  0  0]
#  [ 0  0 18  0  0]
#  [ 1  0  0 18  1]
#  [ 0  0  0  1 21]]

# %%
joblib.dump(dt,'waste Type classification decision tree.pkl')
# Out:
# ['waste Type classification decision tree.pkl']

# %%
dt_accuracy = accuracy_score(y_test, dt_pred)
lr_accuracy = accuracy_score(y_test, lr_pred)

print("Decision Tree :", dt_accuracy)

print("Logistic Regression :", lr_accuracy)

if dt_accuracy > lr_accuracy:
    print("Decision Tree performed better.")
elif lr_accuracy > dt_accuracy:
    print("Logistic Regression performed better.")
else:
    print("Both models performed equally.")
# Out:
# Decision Tree : 0.95
# Logistic Regression : 0.9
# Decision Tree performed better.

# %%
new_sample = [[90,65,3,0,1]]

prediction = dt.predict(new_sample)

print("Predicted Waste Type:")

print(encoder.inverse_transform(prediction))
# Out:
# Predicted Waste Type:
# ['Organic']
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
import joblib

joblib.dump(lr,'waste_classification1.pkl')
# Out:
# ['waste_classification1.pkl']
